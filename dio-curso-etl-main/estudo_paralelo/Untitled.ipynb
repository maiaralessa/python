# %%
import pandas as pd

# %%
dt = pd.read_csv("glpi.csv", sep=";", parse_dates=['Data de abertura'])
dt
# Out:
#          ID                                             Título  Unnamed: 2  \
# 0   154 631                                        Erro e-jade         NaN
# 1   154 585               [PMD 29083] solicitação com urgência         NaN
# 2   154 596  [PMD 29231] Fwd: Dificuldade de acessar o eJad...         NaN
# 3   154 584  Solicito providencias quanto o diário de bordo...         NaN
# 4   154 559                             atualização no sistema         NaN
# 5   154 580            [PMD 29038] solicitação para arrumar km         NaN
# 6   154 294                            GERAR PEDIDO DE EMPENHO         NaN
# 7   154 176                 problemas com os itens disponiveis         NaN
# 8   154 085                                  CONTRATO 21/2020.         NaN
# 9   153 946  [PMD 29205] - ERRO NO E-JADE - Certificado de ...         NaN
# 10  152 946               [PMD 28961] URGENTE - ERRO NO E-JADE         NaN
# ...

# %%
dt.dtypes
# Out:
# ID                          object
# Título                      object
# Unnamed: 2                 float64
# Data de abertura    datetime64[ns]
# Categoria                   object
# dtype: object

# %%
dt.Data de abertura.dt.month
# Out:
#   File "C:\Users\MAIARA~1.LES\AppData\Local\Temp/ipykernel_2340/4168720784.py", line 1
#     dt.Data de abertura.dt.month
#             ^
# SyntaxError: invalid syntax
